# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
import re
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z]', ' ', text)
    words = text.split()
    words = [w for w in words if w not in stop_words]  # use preloaded set
    return " ".join(words)

# %%
df = pd.read_csv("spam_ham_dataset.csv")
# df = pd.get_dummies(df, columns = ['label'],drop_first=True)
df['label'] = df['label'].map({'ham':0, 'spam':1})
df.head()
# Out:
#    Unnamed: 0  label                                               text  \
# 0         605      0  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349      0  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624      0  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685      1  Subject: photoshop , windows , office . cheap ...
# 4        2030      0  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
df['message clean'] = df['text'].apply(preprocess_text)
df.head()
# Out:
#    Unnamed: 0  label                                               text  \
# 0         605      0  Subject: enron methanol ; meter # : 988291\r\n...
# 1        2349      0  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2        3624      0  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3        4685      1  Subject: photoshop , windows , office . cheap ...
# 4        2030      0  Subject: re : indian springs\r\nthis deal is t...
#
#    label_num                                      message clean
# 0          0  subject enron methanol meter follow note gave ...
# 1          0  subject hpl nom january see attached file hpln...
# 2          0  subject neon retreat ho ho ho around wonderful...
# 3          1  subject photoshop windows office cheap main tr...
# 4          0  subject indian springs deal book teco pvr reve...

# %%
X_train, X_test, Y_train,Y_test = train_test_split(df['text'],df['label'],test_size = 0.3,random_state=42)

# %%
Vectorizer = TfidfVectorizer()
X_train_vec = Vectorizer.fit_transform(X_train)
X_test_vec = Vectorizer.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train_vec,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_vec)


print(f"Model Accuracy : {accuracy_score(Y_test,y_pred):.2f}")
scores = cross_val_score(model, Vectorizer.transform(df['message clean']), df['label'], cv=5)
print("Cross-validation scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Model Accuracy : 0.98
# Cross-validation scores: [0.9826087  0.9787234  0.99226306 0.98355899 0.98839458]
# Mean Accuracy: 0.9851097468673785
